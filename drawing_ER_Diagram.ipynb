# %% [markdown]
# # Homework 1: ER
#
# - 이름: 윤다영
# - 학번: 2202002265
# - 제출일: 2023-03-24

# %% [markdown]
# ## What to do:
# - 각 문항의 Data Requirements를 만족하는 ER Diagram (교재에 있는 Chen's Notation)을 (예쁘게 색깔 펜을 이용하여) 그린다.
# - 그린 그림을 스캔하거나, 카메라로 찍어서 그림 파일은 만든다.
# - 그림 파일을 Answer cell에 Copy (CTRL+C), Paste (CTRL + V)한다.

# %% [markdown]
# ## Problem 1. (10pts)
# ----
# ### Data Requirements: Football League
# A database is being constructed to keep track of the teams and games of a
# sports league.
#
# - A football team has a number of players, not all of whom participate in each game.
# - A player is affiliated to only one team.
# - It is desired to keep track of the players participating in each game for each team, the positions they played in that game.

# %% [markdown]
# ### Answer
# ![image.png](data:image/png;base64,...)
# ----

# %% [markdown]
# ## Problem 2. (10pts)
# ----
#
# ### Data Requirements: Rental Company
# - A car rental company has cars and customers.
# - A rental contract is signed by a customer for a specific car.
# - We need to keep track of the rental start and end dates, the daily rental rate, and the total cost of the rental.

# %% [markdown]
# ### Answer
# ![image.png](data:image/png;base64,...)
# ----

# %% [markdown]
# ## Problem 3. (20pts)
# ----
#
#
# ### Data Requirements: University DB
# - The university keeps track of each student's name, student number, social security number, current address and phone, permanent address and phone, birthdate, sex, class (freshman, sophomore, ..., graduate), major department, minor department (if any), and degree program (B.A., B.S., ..., Ph.D.). Some user applications need to refer to the city, state, and zip of the student's permanent address, and to the student's last name. Both social security number and student number have unique values for each student.
# - Each department is described by a name, department code, office number, office phone, and college. Both name and code have unique values for each department.
# - Each course has a course name, description, course number, number of semester hours, level, and offering department. The value of course number is unique for each course.
# -  Each section has an instructor, semester, year, course, and section number. The section number distinguishes different sections of the same course that are taught during the same semester/year; its values are 1, 2, 3, ...; up to the number of sections taught during each semester.
# - A grade report has a student, section, letter grade, and numeric grade (0, 1, 2, 3, 4 for F, D, C, B, A, respectively).

# %% [markdown]
# ### Answer
# ![image.png](data:image/png;base64,...)
# ----

# %% [markdown]
# ## Problem 4. (20pts)
# ----
#
# ### Data Requirements: Online Shopping System
# - Customers can place orders for one or more products. Each order is associated with a single customer, and each order can contain one or more products.
# - Each product is associated with a single category, and each category can contain one or more products.
# - Each customer can have one or more addresses associated with their account.
# - Each product can have one or more reviews associated with it.
# - Each order is associated with a single payment, and each payment can be associated with one or more orders.
# ```

# %% [markdown]
# ### Answer
# ![image.png](data:image/png;base64,...)
# ----

# %% [markdown]
# ## Problem 5. (20pts)
# ----
#
# ### Database Requirements: Social Media Platform:
#
# - Each user can create zero or more posts, and each post can be associated with one user.
# - Each user can be associated with zero or more other users as friends.
# - Each user can create zero or more comments, and each comment can be associated with one user.
# - Each post can have zero or more comments associated with it, and each comment can be associated with one post.
# - Each user can be associated with zero or more groups, and each group can have zero or more users associated with it.

# %% [markdown]
# ### Answer
# ![image.png](data:image/png;base64,...)
# ----

# %% [markdown]
# ## Ethics:
# If you cheat, you will get negative of the total points.
# If the homework total is 20 and you cheat, you get -20.

# %% [markdown]
# ## What to submit
#
# - Goto "File -> Print Preview"
# - Print the page as pdf
# - Submit the pdf file in google classroom
# - Pdf file name must be in a form of: homework_1_홍길동_202300001.pdf
# - No late homeworks will be accepted
